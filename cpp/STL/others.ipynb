# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# Note: push_back can't crate pairs in-place but emplace_back can

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Uses a maxheap or a minheap

# %% [markdown]
# ![image.png](attachment:image.png)
#
# No duplicate Values can be stored
# Multi-set -- duplicates can be stored
# Unordered-set -- in any order but not any duplicates

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
